# %%
import ipyleaflet
import json
import pandas as pd
from ipywidgets import link, FloatSlider
from branca.colormap import linear
import random
import geopandas

#geo_json_data = json.load(open("us-states.json"))
m = ipyleaflet.Map(center=(34, -118), zoom=10)
#unemployment = pd.read_csv("US_Unemployment_Oct2012.csv")
la = path = "data/LACity/LACity.shp"
lacity = geopandas.read_file(path)

# %%
idlist = (lacity["fid"]-1).tolist()
idlist = [str(int(x)) for x in idlist]
population = dict(
    zip(idlist, lacity["pop2010"].tolist())
)

# %%
lacity_json_str = lacity.to_json()
lacity_json_dic = json.loads(lacity_json_str)

# %%
jpype.startJVM("-Xmx20480m", classpath = ["./Pineapple.jar"])
w = rook.from_dataframe(lacity)
sum_attr = 'pop2010'
sum_low = slider.value
print(sum_low)
dis_attr = 'households'
non_attr = 'pop_16up'
inf = java.lang.Double.POSITIVE_INFINITY
p, regions = emp.emp(lacity, w, dis_attr, non_attr, -inf, inf, non_attr, -inf, inf, non_attr, -inf, inf, sum_attr, sum_low, inf, -inf, inf)
region = dict(
    zip(idlist, regions)
)
# Out:
# 76523.8

# %%
layer = ipyleaflet.Choropleth(
    geo_data=lacity_json_dic,
    choro_data=region,
    colormap=linear.RdBu_11,
    style={"fillOpacity": 0.8, "dashArray": "5, 5"},
)

# %%
m = ipyleaflet.Map(center=(34, -118), zoom=9)
m.add_layer(layer)
m
# Out:
# Map(center=[34, -118], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
slider = FloatSlider(min=-1, max=200000, continuous_update=False)
sum_low = slider.value
slider
# Out:
# FloatSlider(value=0.0, continuous_update=False, max=200000.0, min=-1.0)

# %%
m
# Out:
# Map(center=[34, -118], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
# To add callback for style
def compute_style(feature, colormap, choro_data):
    print(feature)
    return {
        "fillColor": colormap(choro_data),
        "color": "black",
        "weight": 0,
    }

# %%
layer.style_callback = compute_style

# %%
def recompute_label(feature, colormap, choro_data):
    w = rook.from_dataframe(lacity)
    sum_attr = 'pop2010'
    sum_low = slider.value
    print(sum_low)
    dis_attr = 'households'
    non_attr = 'pop_16up'
    inf = java.lang.Double.POSITIVE_INFINITY
    p, regions = emp.emp(lacity, w, dis_attr, non_attr, -inf, inf, non_attr, -inf, inf, non_attr, -inf, inf, sum_attr, sum_low, inf, -inf, inf) 
    
    region = dict(
        zip(idlist, regions)
    )
    choro_data=region[feature]
    print(choro_data)
    return {
        "fillColor": colormap(choro_data),
        "color": "black",
        "weight": 0,
    }

# %%
slider = FloatSlider(min=layer.value_min, max=layer.value_max, continuous_update=False)
slider.value = layer.value_min
link((slider, "value"), (layer, "value_min"))
slider
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24688\1514338386.py in <module>
# ----> 1 slider = FloatSlider(min=layer.value_min, max=layer.value_max, continuous_update=False)
#       2 slider.value = layer.value_min
#       3 link((slider, "value"), (layer, "value_min"))
#       4 slider
#
# NameError: name 'layer' is not defined

# %%
slider = FloatSlider(min=-1, max=100000, continuous_update=False)
slider.value = layer.value_min
link((slider, "value"), (layer, "value_min"))
slider
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24688\196637771.py in <module>
#       1 slider = FloatSlider(min=-1, max=100000, continuous_update=False)
# ----> 2 slider.value = layer.value_min
#       3 link((slider, "value"), (layer, "value_min"))
#       4 slider
#
# NameError: name 'layer' is not defined

# %%
import regionalization.emp as emp
import weight.rook as rook
import libpysal 
import time
from libpysal.weights import Queen, Rook, KNN, Kernel, DistanceBand
import numpy as np
import geopandas
import pandas
import matplotlib.pyplot as plt
import jpype
from jpype import java
from jpype import javax

# %%
jpype.startJVM("-Xmx20480m", classpath = ["./Pineapple.jar"])
w = rook.from_dataframe(lacity)
sum_attr = 'pop2010'
sum_low = slider.value
print(sum_low)
dis_attr = 'households'
non_attr = 'pop_16up'
inf = java.lang.Double.POSITIVE_INFINITY
p, regions = emp.emp(lacity, w, dis_attr, non_attr, -inf, inf, non_attr, -inf, inf, non_attr, -inf, inf, sum_attr, sum_low, inf, -inf, inf)
region = dict(
    zip(idlist, regions)
)
# Out:
# 0.0

# %%
regions
# Out:
# array([  1,   1,   3, ..., 933, 968, 908])

# %%
regions
# Out:
# array([  1,   1,   3, ..., 933, 968, 908])

# %%
region = dict(
    zip(idlist, regions)
)

# %%
linear.YlOrBr_04.to_step(10)
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#ffffd4ff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
linear.RdBu_11
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#67001fff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#69001fff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#6a011fff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#6c011fff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#6e0220ff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#6f0220ff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#710320ff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#730320ff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#740421ff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#760421ff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#780521ff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#790522ff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
linear.GnBu_09
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#f7fcf0ff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#f7fcf0ff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#f7fcf0ff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#f6fcefff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#f6fcefff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#f5fcefff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#f5fceeff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#f5fbeeff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#f4fbedff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#f4fbedff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#f3fbedff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#f3fbecff;stroke-width:2;" /><line x1="12" y1=
# ...

# %%
layer.colormap = linear.RdBu_11

# %%
layer.value_min
# Out:
# 21886.0

# %%
from ipywidgets import Text, HTML
from ipyleaflet import WidgetControl, GeoJSON


html = HTML(
    """
    <h4> Name </h4>
    Hover over a state
"""
)
html.layout.margin = "0px 10px 10px 10px"
control = WidgetControl(widget=html, position="topright")
m.add_control(control)


def update_html(feature, id, **kwargs):
    html.value = """
        State name:  
        <b>{}\n</b>
        {} 
    """.format(
        id, feature["properties"]["name"]
    )


layer.on_hover(update_html)
