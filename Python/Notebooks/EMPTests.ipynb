# %%
from pineapple import regionalization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16328/3305337267.py in <module>
# ----> 1 from pineapple import regionalization
#
# ModuleNotFoundError: No module named 'pineapple'
